# %%
import torch
import pytorch_lightning as pl
import numpy as np
from core.data import GridDataModule
from core.model import AutoEncoder
from core.utilities import Logger, make_gif

# %%
log_dir = 'lightning_logs/'
version = 'ignition_qcnn_update_5/'
checkpoint = 'checkpoints/last.ckpt'
data_dir = 'data/ignition_center_cut'

# dm = GridDataModule(data_dir=data_dir,
#                     dimension=2,
#                     batch_size=512,
#                     size=50,
#                     stride=50,
#                     flatten=False,
#                     channels=[1])

# logger = Logger(save_dir=log_dir, 
#                 version=version)
# trainer = pl.Trainer(accelerator='gpu', devices=1, logger=logger)

model = AutoEncoder.load_from_checkpoint(log_dir+version+checkpoint,
                                         input_shape=(1,1,50**2))

# %% [markdown]
# # Model Size

# %%
print(model)
# Out:
# AutoEncoder(
#   (encoder): Encoder(
#     (activation1): CELU(alpha=1.0)
#     (activation2): CELU(alpha=1.0)
#     (cnn): Sequential(
#       (0): QuadConvBlock(
#         (activation1): CELU(alpha=1.0)
#         (activation2): CELU(alpha=1.0)
#         (conv1): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=1, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(1, 1))
#           )
#         )
#         (norm1): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=4, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(1, 4))
#           )
#         )
#         (norm2): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): QuadConvBlock(
#         (activation1): CELU(alpha=1.0)
#         (activation2): CELU(alpha=1.0)
#         (conv1): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=16, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(4, 4))
#           )
#         )
#         (norm1): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=64, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(4, 16))
#           )
#         )
#         (norm2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): QuadConvBlock(
#         (activation1): CELU(alpha=1.0)
#         (activation2): CELU(alpha=1.0)
#         (conv1): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=256, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(16, 16))
#           )
#         )
#         (norm1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=256, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(16, 16))
#           )
#         )
#         (norm2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): QuadConvBlock(
#         (activation1): CELU(alpha=1.0)
#         (activation2): CELU(alpha=1.0)
#         (conv1): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=256, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(16, 16))
#           )
#         )
#         (norm1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=512, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(16, 32))
#           )
#         )
#         (norm2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (flat): Flatten(start_dim=1, end_dim=-1)
#     (linear): Sequential(
#       (0): ParametrizedLinear(
#         in_features=3200, out_features=10, bias=True
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _SpectralNorm()
#           )
#         )
#       )
#       (1): CELU(alpha=1.0)
#       (2): ParametrizedLinear(
#         in_features=10, out_features=10, bias=True
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _SpectralNorm()
#           )
#         )
#       )
#       (3): CELU(alpha=1.0)
#     )
#   )
#   (decoder): Decoder(
#     (activation1): CELU(alpha=1.0)
#     (activation2): CELU(alpha=1.0)
#     (unflat): Unflatten(dim=1, unflattened_size=torch.Size([32, 100]))
#     (linear): Sequential(
#       (0): ParametrizedLinear(
#         in_features=10, out_features=10, bias=True
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _SpectralNorm()
#           )
#         )
#       )
#       (1): CELU(alpha=1.0)
#       (2): ParametrizedLinear(
#         in_features=10, out_features=3200, bias=True
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): _SpectralNorm()
#           )
#         )
#       )
#       (3): CELU(alpha=1.0)
#     )
#     (cnn): Sequential(
#       (0): QuadConvBlock(
#         (activation1): CELU(alpha=1.0)
#         (activation2): CELU(alpha=1.0)
#         (conv1): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=256, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(16, 16))
#           )
#         )
#         (norm1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=512, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(32, 16))
#           )
#         )
#         (norm2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): QuadConvBlock(
#         (activation1): CELU(alpha=1.0)
#         (activation2): CELU(alpha=1.0)
#         (conv1): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=256, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(16, 16))
#           )
#         )
#         (norm1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=256, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(16, 16))
#           )
#         )
#         (norm2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): QuadConvBlock(
#         (activation1): CELU(alpha=1.0)
#         (activation2): CELU(alpha=1.0)
#         (conv1): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=16, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(4, 4))
#           )
#         )
#         (norm1): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=64, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(16, 4))
#           )
#         )
#         (norm2): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): QuadConvBlock(
#         (activation1): Identity()
#         (activation2): CELU(alpha=1.0)
#         (conv1): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=1, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(1, 1))
#           )
#         )
#         (norm1): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): QuadConvLayer(
#           (G): Sequential(
#             (0): Linear(in_features=2, out_features=8, bias=False)
#             (1): Sin()
#             (2): Linear(in_features=8, out_features=8, bias=False)
#             (3): Sin()
#             (4): Linear(in_features=8, out_features=8, bias=False)
#             (5): Sin()
#             (6): Linear(in_features=8, out_features=4, bias=False)
#             (7): Unflatten(dim=1, unflattened_size=(4, 1))
#           )
#         )
#         (norm2): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (output_activation): Tanh()
# )

# %% [markdown]
# # Testing

# %%
trainer.test(model=model, datamodule=dm)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 0it [00:00, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      test_err_epoch         0.2745022475719452
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_err_epoch': 0.2745022475719452}]

# %%
dm.setup(stage="fit")
make_gif(trainer, dm, model)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: 0it [00:00, ?it/s]
